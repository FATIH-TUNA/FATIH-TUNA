# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veri=pd.read_csv("https://raw.githubusercontent.com/mk-gurucharan/Regression/master/IceCreamData.csv")
veri.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
veri.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
x=veri['Temperature']
y=veri['Revenue']
x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
from sklearn.model_selection import*
x_egitim,x_test,y_egitim,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.ensemble import BaggingRegressor
bgmodel=BaggingRegressor(random_state=0,n_estimators=21)
bgmodel.fit(x_egitim,y_egitim)
bgtahmin_egitim=bgmodel.predict(x_egitim)
bgtahmin_test=bgmodel.predict(x_test)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:429: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)

# %%
from sklearn.metrics import*
print("\nEGITIM R2 ORANI: %.2f"%r2_score(y_egitim,bgtahmin_egitim))
# Out:
# EGITIM R2 ORANI: 0.99

# %%
print("\nTEST R2 ORANI: %.2f"%r2_score(y_test,bgtahmin_test))
# Out:
# TEST R2 ORANI: 0.98

# %%
from sklearn.model_selection import*
param={'n_estimators':np.arange(2,30)}
grid=GridSearchCV(bgmodel,param_grid=param,cv=10)
grid.fit(x_egitim,y_egitim)
print(grid.best_params_)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:429: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:429: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:429: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# ...

# %%
while True:
    sicak=float(input("\nBIR SICAKLIK DEGERI GIRINIZ: "))
    dene=np.array(sicak).reshape(-1,1)
    deneme=bgmodel.predict(dene)
    print(deneme)
    cevap=str(input("\nISLEM DEVAM ETSIN MI: ")).upper()
    if cevap=='E':
        continue
    else:
        break
